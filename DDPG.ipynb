# %% [markdown]
# <a href="https://colab.research.google.com/github/ArshT/Reinforcement_Learning_Basic/blob/master/DDPG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install box2d-py
import gym
env = gym.make("LunarLander-v2")
# Out:
# Collecting box2d-py
#   Downloading https://files.pythonhosted.org/packages/87/34/da5393985c3ff9a76351df6127c275dcb5749ae0abbe8d5210f06d97405d/box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448kB)
#      |████████████████████████████████| 450kB 6.7MB/s
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torch as T
from torch.distributions import MultivariateNormal

class OUActionNoise(object):
    def __init__(self, mu, sigma=0.15, theta=.2, dt=1e-2, x0=None):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dt
        self.x0 = x0
        self.reset()

    def __call__(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
            self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(
                                                            self.mu, self.sigma)



class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, input_shape))
        self.new_state_memory = np.zeros((self.mem_size, input_shape))
        self.action_memory = np.zeros((self.mem_size, n_actions))
        self.reward_memory = np.zeros((self.mem_size,1))
        self.terminal_memory = np.zeros((self.mem_size,1), dtype=np.float32)

    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = 1 - done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)

        batch = np.random.choice(max_mem, batch_size)

        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal


class Actor(nn.Module):
  def __init__(self,alpha,input_dims,fc1_dims,fc2_dims,action_dims):
    super(Actor,self).__init__()

    self.fc1 = nn.Linear(input_dims,fc1_dims)
    f1 = 1 / np.sqrt(self.fc1.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
    torch.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
    self.bn1 = nn.LayerNorm(fc1_dims)

    self.fc2 = nn.Linear(fc1_dims,fc2_dims)
    f2 = 1 / np.sqrt(self.fc2.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
    torch.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
    self.bn2 = nn.LayerNorm(fc2_dims)

    f3 = 0.003
    self.mu = nn.Linear(fc2_dims, action_dims)
    torch.nn.init.uniform_(self.mu.weight.data, -f3, f3)
    torch.nn.init.uniform_(self.mu.bias.data, -f3, f3)

    self.device = torch.device('cuda' if T.cuda.is_available() else 'cpu')
    self.optimizer = optim.Adam(self.parameters(), lr=alpha)

    self.to(self.device)
  
  def forward(self,state):
    x = F.relu(self.bn1(self.fc1(state)))
    x = F.relu(self.bn2(self.fc2(x)))
    action_mu = torch.tanh(self.mu(x))

    return action_mu


class Critic(nn.Module):
  def __init__(self,beta,input_dims,fc1_dims,fc2_dims,action_dims):
    super(Critic,self).__init__()

    self.fc1 = nn.Linear(input_dims,fc1_dims)
    f1 = 1 / np.sqrt(self.fc1.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
    torch.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
    self.bn1 = nn.LayerNorm(fc1_dims)

    self.fc2 = nn.Linear(fc1_dims,fc2_dims)
    f2 = 1 / np.sqrt(self.fc2.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
    torch.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
    self.bn2 = nn.LayerNorm(fc2_dims)

    self.action_value = nn.Linear(action_dims, fc2_dims)

    f3 = 0.0003
    self.q = nn.Linear(fc2_dims, 1)
    torch.nn.init.uniform_(self.q.weight.data, -f3, f3)
    torch.nn.init.uniform_(self.q.bias.data, -f3, f3)

    self.device = torch.device('cuda' if T.cuda.is_available() else 'cpu')
    self.optimizer = optim.Adam(self.parameters(), lr=beta)

    self.to(self.device)
  
  def forward(self,state,action):
    state_value = F.relu(self.bn1(self.fc1(state)))
    state_value = self.bn2(self.fc2(state_value))

    action_value = F.relu(self.action_value(action))

    state_action_value = F.relu(torch.add(state_value,action_value))
    state_action_value = self.q(state_action_value)

    return state_action_value

class Agent(object):
    def __init__(self, alpha, beta, input_dims, tau, env,action_std_decay_rate,
                 min_action_std, gamma=0.99,n_actions=2, max_size=1000000, layer1_size=400,
                 layer2_size=300, batch_size=64,action_std_init=0.6):
      
      self.tau = tau
      self.gamma = gamma
      self.batch_size = batch_size
      self.memory = ReplayBuffer(max_size, input_dims, n_actions)
      self.env = env
      self.action_dims=n_actions
      self.action_std_decay_rate = action_std_decay_rate
      self.min_action_std = min_action_std

      self.action_std = action_std_init
      self.action_var = torch.full((n_actions,), self.action_std * self.action_std).to('cpu')

      self.actor = Actor(alpha=alpha,input_dims=input_dims,fc1_dims=layer1_size,fc2_dims=layer2_size,action_dims=n_actions)
      self.target_actor = Actor(alpha=alpha,input_dims=input_dims,fc1_dims=layer1_size,fc2_dims=layer2_size,action_dims=n_actions)

      self.critic = Critic(beta=beta,input_dims=input_dims,fc1_dims=layer1_size,fc2_dims=layer2_size,action_dims=n_actions)
      self.target_critic = Critic(beta=beta,input_dims=input_dims,fc1_dims=layer1_size,fc2_dims=layer2_size,action_dims=n_actions)

      self.noise = OUActionNoise(mu=np.zeros(n_actions))
      self.update_network_parameters(tau=1)
    
    def set_action_std(self, new_action_std):
      self.action_std = new_action_std
      self.action_var = torch.full((self.action_dims,), self.action_std * self.action_std).to('cpu')
    

    def decay_action_std(self):
        print("--------------------------------------------------------------------------------------------")
        
        self.action_std = self.action_std - self.action_std_decay_rate
        self.action_std = round(self.action_std, 4)
        if (self.action_std <= self.min_action_std):
          self.action_std = self.min_action_std
          print("setting actor output action_std to min_action_std : ", self.action_std)
          self.set_action_std(self.action_std)
        
        else:
          print("setting actor output action_std to : ", self.action_std)
          self.set_action_std(self.action_std)

        print("--------------------------------------------------------------------------------------------")


    
    def remember(self,state,action,reward,new_state,done):
      self.memory.store_transition(state, action, reward, new_state, done)
    

    def choose_action(self,observation):
      self.actor.eval()
      with torch.no_grad():
        state = torch.FloatTensor(observation).to(self.actor.device)
        action_mean = self.actor.forward(state).to(self.actor.device)
        cov_mat = torch.diag(self.action_var).unsqueeze(dim=0)
        dist = MultivariateNormal(action_mean, cov_mat)
      
      action = dist.sample()
      low = self.env.action_space.low[0]
      high = self.env.action_space.high[0]
      action = torch.clamp(action,low,high)

      self.actor.train()
      
      return action.detach().cpu().numpy().flatten()
    

    def learn(self):
      if self.memory.mem_cntr < self.batch_size:
        return
      state, action, reward, new_state, done = self.memory.sample_buffer(self.batch_size)
      
      reward = torch.tensor(reward, dtype=torch.float).to(self.critic.device)
      done = torch.tensor(done).to(self.critic.device)
      new_state = torch.tensor(new_state, dtype=torch.float).to(self.critic.device)
      action = torch.tensor(action, dtype=torch.float).to(self.critic.device)
      state = torch.tensor(state, dtype=torch.float).to(self.critic.device)
      
      self.target_actor.eval()
      self.target_critic.eval()
      self.critic.eval()
      target_actions = self.target_actor.forward(new_state)
      critic_value_ = self.target_critic.forward(new_state, target_actions)
      critic_value = self.critic.forward(state, action)


      #target = []
      #for j in range(self.batch_size):
       # target.append(reward[j] + self.gamma*critic_value_[j]*done[j])
      target = reward + self.gamma*critic_value_*done
      target = torch.tensor(target).to(self.critic.device)
      target = target.view(self.batch_size, 1)

      self.critic.train()
      self.critic.optimizer.zero_grad()
      critic_loss = F.mse_loss(target, critic_value)
      critic_loss.backward()
      self.critic.optimizer.step()

      self.critic.eval()
      self.actor.optimizer.zero_grad()
      mu = self.actor.forward(state)
      self.actor.train()
      actor_loss = -self.critic.forward(state, mu)
      actor_loss = torch.mean(actor_loss)
      actor_loss.backward()
      self.actor.optimizer.step()

      self.update_network_parameters()

    def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_dict = dict(target_critic_params)
        target_actor_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                      (1-tau)*target_critic_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)

        for name in actor_state_dict:
            actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                      (1-tau)*target_actor_dict[name].clone()
        self.target_actor.load_state_dict(actor_state_dict)

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=00.000025, input_dims=8, tau=0.001, env=env,action_std_decay_rate=0.05,
                 min_action_std=0.05,batch_size=64,  layer1_size=400, layer2_size=300, n_actions=2,action_std_init=0.6)

action_std_decay_freq = int(7.5e4) 
#action_std_decay_freq = int(2000) 

score_history = []
timesteps = 0
for i in range(5000):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
        timesteps += 1
        
        if timesteps % action_std_decay_freq == 0:
            agent.decay_action_std()
            
        if done:
            break
        #env.render()
    score_history.append(score)

    if i % 10 == 0:
        print('episode ', i, 'score %.2f' % score,
          'trailing 10 games avg %.3f' % np.mean(score_history[-10:]),
          'timesteps:',timesteps)

    print('episode ', i, 'score %.2f' % score,
          'trailing 100 games avg %.3f' % np.mean(score_history[-100:]),
          'timesteps:',timesteps)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:232: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# episode  0 score -293.41 trailing 10 games avg -293.411 timesteps: 112
# episode  0 score -293.41 trailing 100 games avg -293.411 timesteps: 112
# episode  1 score -246.05 trailing 100 games avg -269.731 timesteps: 215
# episode  2 score -420.49 trailing 100 games avg -319.985 timesteps: 329
# episode  3 score -240.22 trailing 100 games avg -300.044 timesteps: 446
# episode  4 score -275.83 trailing 100 games avg -295.201 timesteps: 558
# episode  5 score -206.15 trailing 100 games avg -280.359 timesteps: 739
# episode  6 score -348.58 trailing 100 games avg -290.105 timesteps: 926
# episode  7 score -240.98 trailing 100 games avg -283.964 timesteps: 1077
# episode  8 score -244.96 trailing 100 games avg -279.630 timesteps: 1292
# episode  9 score -202.92 trailing 100 games avg -271.959 timesteps: 1503
# episode  10 score -371.49 trailing 10 games avg -279.767 timesteps: 1690
# episode  10 score -371.49 trailing 100 games avg -281.007 timesteps: 1690
# episode  11 score -242.52 trailing 100 games avg -277.800 timesteps: 1794
# episode  12 score -364.73 trailing 100 games avg -284.487 timesteps: 1981
# episode  13 score -300.58 trailing 100 games avg -285.636 timesteps: 2107
# episode  14 score -195.27 trailing 100 games avg -279.612 timesteps: 2370
# episode  15 score -30.39 trailing 100 games avg -264.036 timesteps: 2508
# episode  16 score -276.67 trailing 100 games avg -264.779 timesteps: 2625
# episode  17 score -358.33 trailing 100 games avg -269.977 timesteps: 2873
# episode  18 score -524.78 trailing 100 games avg -283.387 timesteps: 3057
# episode  19 score -238.89 trailing 100 games avg -281.162 timesteps: 3268
# episode  20 score -222.23 trailing 10 games avg -275.440 timesteps: 3460
# episode  20 score -222.23 trailing 100 games avg -278.356 timesteps: 3460
# episode  21 score -308.50 trailing 100 games avg -279.726 timesteps: 3609
# episode  22 score -262.58 trailing 100 games avg -278.981 timesteps: 3721
# episode  23 score -345.22 trailing 100 games avg -281.741 timesteps: 4001
# episode  24 score -327.01 trailing 100 games avg -283.552 timesteps: 4191
# episode  25 score -408.81 trailing 100 games avg -288.369 timesteps: 4628
# episode  26 score -252.71 trailing 100 games avg -287.049 timesteps: 4793
# episode  27 score -362.92 trailing 100 games avg -289.758 timesteps: 5115
# episode  28 score -406.48 trailing 100 games avg -293.783 timesteps: 5958
# episode  29 score -384.23 trailing 100 games avg -296.798 timesteps: 6162
# episode  30 score -326.80 trailing 10 games avg -338.526 timesteps: 6371
# episode  30 score -326.80 trailing 100 games avg -297.766 timesteps: 6371
# episode  31 score -155.97 trailing 100 games avg -293.335 timesteps: 7371
# episode  32 score -140.47 trailing 100 games avg -288.702 timesteps: 8371
# episode  33 score -111.72 trailing 100 games avg -283.497 timesteps: 9371
# episode  34 score -283.70 trailing 100 games avg -283.503 timesteps: 9530
# episode  35 score -133.70 trailing 100 games avg -279.341 timesteps: 9834
# episode  36 score -117.99 trailing 100 games avg -274.981 timesteps: 10834
# episode  37 score -139.62 trailing 100 games avg -271.419 timesteps: 11834
# episode  38 score -124.62 trailing 100 games avg -267.655 timesteps: 12834
# episode  39 score -124.64 trailing 100 games avg -264.079 timesteps: 13834
# episode  40 score -138.62 trailing 10 games avg -147.104 timesteps: 14834
# episode  40 score -138.62 trailing 100 games avg -261.019 timesteps: 14834
# episode  41 score -104.71 trailing 100 games avg -257.297 timesteps: 15834
# episode  42 score -49.33 trailing 100 games avg -252.461 timesteps: 16834
# episode  43 score -142.89 trailing 100 games avg -249.971 timesteps: 17651
# episode  44 score -35.63 trailing 100 games avg -245.208 timesteps: 18164
# episode  45 score -37.25 trailing 100 games avg -240.687 timesteps: 19164
# episode  46 score -68.63 trailing 100 games avg -237.026 timesteps: 20164
# episode  47 score 44.39 trailing 100 games avg -231.163 timesteps: 21164
# episode  48 score -73.52 trailing 100 games avg -227.946 timesteps: 21779
# episode  49 score -170.25 trailing 100 games avg -226.792 timesteps: 22727
# episode  50 score 55.58 trailing 10 games avg -58.224 timesteps: 23727
# episode  50 score 55.58 trailing 100 games avg -221.255 timesteps: 23727
# episode  51 score -101.25 trailing 100 games avg -218.947 timesteps: 24400
# episode  52 score 11.81 trailing 100 games avg -214.594 timesteps: 25400
# episode  53 score 34.15 trailing 100 games avg -209.987 timesteps: 26400
# episode  54 score -126.11 trailing 100 games avg -208.462 timesteps: 27225
# episode  55 score 33.18 trailing 100 games avg -204.147 timesteps: 28225
# episode  56 score 53.28 trailing 100 games avg -199.631 timesteps: 29225
# episode  57 score -73.67 trailing 100 games avg -197.459 timesteps: 29786
# episode  58 score 31.95 trailing 100 games avg -193.571 timesteps: 30786
# episode  59 score 33.71 trailing 100 games avg -189.783 timesteps: 31786
# episode  60 score -22.65 trailing 10 games avg -12.559 timesteps: 32360
# episode  60 score -22.65 trailing 100 games avg -187.043 timesteps: 32360
# episode  61 score -94.49 trailing 100 games avg -185.550 timesteps: 32933
# episode  62 score -0.01 trailing 100 games avg -182.605 timesteps: 33933
# episode  63 score -36.70 trailing 100 games avg -180.325 timesteps: 34487
# episode  64 score 68.01 trailing 100 games avg -176.505 timesteps: 35487
# episode  65 score 45.18 trailing 100 games avg -173.146 timesteps: 36487
# episode  66 score -12.00 trailing 100 games avg -170.740 timesteps: 36994
# episode  67 score -104.26 trailing 100 games avg -169.763 timesteps: 37397
# episode  68 score -49.52 trailing 100 games avg -168.020 timesteps: 38397
# episode  69 score -26.61 trailing 100 games avg -166.000 timesteps: 39397
# episode  70 score -41.38 trailing 10 games avg -25.176 timesteps: 40397
# episode  70 score -41.38 trailing 100 games avg -164.245 timesteps: 40397
# episode  71 score -148.05 trailing 100 games avg -164.020 timesteps: 41050
# episode  72 score -266.29 trailing 100 games avg -165.421 timesteps: 41849
# episode  73 score 35.21 trailing 100 games avg -162.709 timesteps: 42849
# episode  74 score -126.99 trailing 100 games avg -162.233 timesteps: 43507
# episode  75 score 82.76 trailing 100 games avg -159.010 timesteps: 44507
# episode  76 score -128.25 trailing 100 games avg -158.610 timesteps: 45076
# episode  77 score 48.69 trailing 100 games avg -155.952 timesteps: 46076
# episode  78 score -116.24 trailing 100 games avg -155.450 timesteps: 46675
# episode  79 score -129.41 trailing 100 games avg -155.124 timesteps: 47370
# episode  80 score 25.54 trailing 10 games avg -72.304 timesteps: 48370
# episode  80 score 25.54 trailing 100 games avg -152.894 timesteps: 48370
# episode  81 score -118.28 trailing 100 games avg -152.472 timesteps: 48991
# episode  82 score 0.80 trailing 100 games avg -150.625 timesteps: 49991
# episode  83 score -33.88 trailing 100 games avg -149.235 timesteps: 50991
# episode  84 score -31.40 trailing 100 games avg -147.849 timesteps: 51991
# episode  85 score -13.13 trailing 100 games avg -146.283 timesteps: 52991
# episode  86 score -13.66 trailing 100 games avg -144.758 timesteps: 53991
# episode  87 score -30.95 trailing 100 games avg -143.465 timesteps: 54991
# episode  88 score -32.34 trailing 100 games avg -142.216 timesteps: 55991
# episode  89 score -124.34 trailing 100 games avg -142.018 timesteps: 56820
# episode  90 score -92.38 trailing 10 games avg -48.956 timesteps: 57820
# episode  90 score -92.38 trailing 100 games avg -141.472 timesteps: 57820
# episode  91 score -32.69 trailing 100 games avg -140.290 timesteps: 58820
# episode  92 score -58.45 trailing 100 games avg -139.410 timesteps: 59820
# episode  93 score -296.59 trailing 100 games avg -141.082 timesteps: 59967
# episode  94 score -34.34 trailing 100 games avg -139.958 timesteps: 60967
# episode  95 score 2.41 trailing 100 games avg -138.475 timesteps: 61967
# episode  96 score -45.26 trailing 100 games avg -137.514 timesteps: 62967
# episode  97 score -21.05 trailing 100 games avg -136.326 timesteps: 63967
# episode  98 score -57.69 trailing 100 games avg -135.532 timesteps: 64967
# episode  99 score -4.95 trailing 100 games avg -134.226 timesteps: 65967
# episode  100 score -27.70 trailing 10 games avg -57.633 timesteps: 66967
# episode  100 score -27.70 trailing 100 games avg -131.569 timesteps: 66967
# episode  101 score -50.88 trailing 100 games avg -129.617 timesteps: 67967
# episode  102 score -60.92 trailing 100 games avg -126.021 timesteps: 68967
# episode  103 score -68.86 trailing 100 games avg -124.308 timesteps: 69967
# episode  104 score -24.90 trailing 100 games avg -121.799 timesteps: 70967
# episode  105 score -32.79 trailing 100 games avg -120.065 timesteps: 71967
# episode  106 score -66.88 trailing 100 games avg -117.248 timesteps: 72967
# episode  107 score -196.54 trailing 100 games avg -116.804 timesteps: 73139
# episode  108 score -77.15 trailing 100 games avg -115.125 timesteps: 73364
# episode  109 score -24.83 trailing 100 games avg -113.345 timesteps: 74364
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.55
# --------------------------------------------------------------------------------------------
# episode  110 score -92.08 trailing 10 games avg -69.582 timesteps: 75364
# episode  110 score -92.08 trailing 100 games avg -110.550 timesteps: 75364
# episode  111 score -29.13 trailing 100 games avg -108.416 timesteps: 76364
# episode  112 score -17.39 trailing 100 games avg -104.943 timesteps: 77364
# episode  113 score -37.26 trailing 100 games avg -102.310 timesteps: 78364
# episode  114 score -15.35 trailing 100 games avg -100.511 timesteps: 79364
# episode  115 score -8.65 trailing 100 games avg -100.293 timesteps: 80364
# episode  116 score -218.01 trailing 100 games avg -99.707 timesteps: 80595
# episode  117 score -51.64 trailing 100 games avg -96.640 timesteps: 81595
# episode  118 score -7.69 trailing 100 games avg -91.469 timesteps: 82595
# episode  119 score -30.39 trailing 100 games avg -89.384 timesteps: 83595
# episode  120 score -56.61 trailing 10 games avg -47.212 timesteps: 84595
# episode  120 score -56.61 trailing 100 games avg -87.728 timesteps: 84595
# episode  121 score -29.20 trailing 100 games avg -84.935 timesteps: 85595
# episode  122 score -16.70 trailing 100 games avg -82.476 timesteps: 86595
# episode  123 score -69.70 trailing 100 games avg -79.721 timesteps: 87595
# episode  124 score -29.43 trailing 100 games avg -76.745 timesteps: 88595
# episode  125 score -67.74 trailing 100 games avg -73.334 timesteps: 89595
# episode  126 score -22.98 trailing 100 games avg -71.037 timesteps: 90595
# episode  127 score -79.20 trailing 100 games avg -68.200 timesteps: 91387
# episode  128 score -37.72 trailing 100 games avg -64.512 timesteps: 92387
# episode  129 score -31.49 trailing 100 games avg -60.985 timesteps: 93387
# episode  130 score -36.44 trailing 10 games avg -42.061 timesteps: 94387
# episode  130 score -36.44 trailing 100 games avg -58.081 timesteps: 94387
# episode  131 score -33.54 trailing 100 games avg -56.857 timesteps: 95387
# episode  132 score 0.98 trailing 100 games avg -55.442 timesteps: 96387
# episode  133 score -63.21 trailing 100 games avg -54.957 timesteps: 97387
# episode  134 score 12.27 trailing 100 games avg -51.998 timesteps: 98387
# episode  135 score -39.77 trailing 100 games avg -51.058 timesteps: 99387
# episode  136 score -24.13 trailing 100 games avg -50.120 timesteps: 100387
# episode  137 score 0.65 trailing 100 games avg -48.717 timesteps: 101387
# episode  138 score 9.97 trailing 100 games avg -47.371 timesteps: 102387
# episode  139 score -23.31 trailing 100 games avg -46.358 timesteps: 103387
# episode  140 score 17.04 trailing 10 games avg -14.304 timesteps: 104387
# episode  140 score 17.04 trailing 100 games avg -44.801 timesteps: 104387
# episode  141 score -26.03 trailing 100 games avg -44.014 timesteps: 105387
# episode  142 score -46.60 trailing 100 games avg -43.987 timesteps: 106387
# episode  143 score -21.47 trailing 100 games avg -42.773 timesteps: 107387
# episode  144 score 14.33 trailing 100 games avg -42.273 timesteps: 108387
# episode  145 score 22.45 trailing 100 games avg -41.676 timesteps: 109387
# episode  146 score -46.31 trailing 100 games avg -41.453 timesteps: 110387
# episode  147 score -33.20 trailing 100 games avg -42.229 timesteps: 111387
# episode  148 score -14.99 trailing 100 games avg -41.644 timesteps: 112387
# episode  149 score -1.33 trailing 100 games avg -39.955 timesteps: 113387
# episode  150 score -31.81 trailing 10 games avg -18.498 timesteps: 114387
# episode  150 score -31.81 trailing 100 games avg -40.828 timesteps: 114387
# episode  151 score -7.04 trailing 100 games avg -39.886 timesteps: 115387
# episode  152 score -24.23 trailing 100 games avg -40.247 timesteps: 116387
# episode  153 score -30.57 trailing 100 games avg -40.894 timesteps: 117387
# episode  154 score -80.53 trailing 100 games avg -40.438 timesteps: 117595
# episode  155 score 0.53 trailing 100 games avg -40.765 timesteps: 118595
# episode  156 score -0.12 trailing 100 games avg -41.299 timesteps: 119595
# episode  157 score -5.53 trailing 100 games avg -40.617 timesteps: 120595
# episode  197 score 9.10 trailing 100 games avg -29.134 timesteps: 158933
# episode  198 score -59.08 trailing 100 games avg -29.148 timesteps: 159933
# episode  199 score -50.98 trailing 100 games avg -29.608 timesteps: 160933
# episode  200 score -85.02 trailing 10 games avg -15.218 timesteps: 161933
# episode  200 score -85.02 trailing 100 games avg -30.181 timesteps: 161933
# episode  201 score -34.27 trailing 100 games avg -30.015 timesteps: 162933
# episode  202 score -38.14 trailing 100 games avg -29.787 timesteps: 163933
# episode  203 score -23.59 trailing 100 games avg -29.335 timesteps: 164933
# episode  204 score 45.18 trailing 100 games avg -28.634 timesteps: 165933
# episode  205 score -3.15 trailing 100 games avg -28.337 timesteps: 166933
# episode  206 score 136.11 trailing 100 games avg -26.307 timesteps: 167933
# episode  207 score -71.64 trailing 100 games avg -25.058 timesteps: 168335
# episode  208 score -6.74 trailing 100 games avg -24.354 timesteps: 169335
# episode  209 score -30.84 trailing 100 games avg -24.414 timesteps: 170335
# episode  210 score 31.77 trailing 10 games avg 0.469 timesteps: 171335
# episode  210 score 31.77 trailing 100 games avg -23.176 timesteps: 171335
# episode  211 score 110.75 trailing 100 games avg -21.777 timesteps: 172335
# episode  212 score 123.55 trailing 100 games avg -20.368 timesteps: 173335
# episode  213 score 81.23 trailing 100 games avg -19.183 timesteps: 174335
# episode  214 score 39.61 trailing 100 games avg -18.633 timesteps: 175335
# episode  215 score -92.08 trailing 100 games avg -19.468 timesteps: 175730
# episode  216 score 49.42 trailing 100 games avg -16.793 timesteps: 176730
# episode  217 score -37.62 trailing 100 games avg -16.653 timesteps: 177041
# episode  218 score -25.90 trailing 100 games avg -16.835 timesteps: 178041
# episode  219 score -8.42 trailing 100 games avg -16.616 timesteps: 179041
# episode  220 score 15.31 trailing 10 games avg 25.584 timesteps: 180041
# episode  220 score 15.31 trailing 100 games avg -15.896 timesteps: 180041
# episode  221 score 31.47 trailing 100 games avg -15.290 timesteps: 180218
# episode  222 score 57.17 trailing 100 games avg -14.551 timesteps: 181218
# episode  223 score 64.36 trailing 100 games avg -13.210 timesteps: 182218
# episode  224 score 75.24 trailing 100 games avg -12.164 timesteps: 183218
# episode  225 score 46.38 trailing 100 games avg -11.023 timesteps: 184218
# episode  226 score -0.39 trailing 100 games avg -10.797 timesteps: 185218
# episode  227 score 48.54 trailing 100 games avg -9.519 timesteps: 186218
# episode  228 score 53.12 trailing 100 games avg -8.611 timesteps: 187218
# episode  229 score 87.39 trailing 100 games avg -7.422 timesteps: 188218
# episode  230 score -386.07 trailing 10 games avg 7.720 timesteps: 188616
# episode  230 score -386.07 trailing 100 games avg -10.918 timesteps: 188616
# episode  231 score 56.76 trailing 100 games avg -10.015 timesteps: 189616
# episode  232 score -172.95 trailing 100 games avg -11.755 timesteps: 189801
# episode  233 score -103.04 trailing 100 games avg -12.153 timesteps: 189999
# episode  234 score -82.35 trailing 100 games avg -13.099 timesteps: 190177
# episode  235 score 63.51 trailing 100 games avg -12.066 timesteps: 191177
# episode  236 score -54.74 trailing 100 games avg -12.373 timesteps: 192177
# episode  237 score -13.83 trailing 100 games avg -12.517 timesteps: 193177
# episode  238 score -259.28 trailing 100 games avg -15.210 timesteps: 193410
# episode  239 score -166.52 trailing 100 games avg -16.642 timesteps: 193635
# episode  240 score -126.68 trailing 10 games avg -85.913 timesteps: 193788
# episode  240 score -126.68 trailing 100 games avg -18.079 timesteps: 193788
# episode  241 score -175.71 trailing 100 games avg -19.576 timesteps: 193997
# episode  242 score 16.93 trailing 100 games avg -18.941 timesteps: 194997
# episode  243 score 81.16 trailing 100 games avg -17.914 timesteps: 195997
# episode  244 score 119.98 trailing 100 games avg -16.858 timesteps: 196997
# episode  245 score -5.72 trailing 100 games avg -17.139 timesteps: 197997
# episode  246 score 32.62 trailing 100 games avg -16.350 timesteps: 198997
# episode  247 score -203.35 trailing 100 games avg -18.051 timesteps: 199182
# episode  248 score -0.98 trailing 100 games avg -17.911 timesteps: 200182
# episode  249 score 0.79 trailing 100 games avg -17.890 timesteps: 201182
# episode  250 score 53.45 trailing 10 games avg -8.081 timesteps: 202182
# episode  250 score 53.45 trailing 100 games avg -17.038 timesteps: 202182
# episode  251 score 39.22 trailing 100 games avg -16.575 timesteps: 203182
# episode  252 score 138.36 trailing 100 games avg -14.949 timesteps: 204009
# episode  253 score 65.13 trailing 100 games avg -13.992 timesteps: 205009
# episode  254 score -121.55 trailing 100 games avg -14.402 timesteps: 205213
# episode  255 score -119.17 trailing 100 games avg -15.599 timesteps: 205435
# episode  256 score 66.71 trailing 100 games avg -14.931 timesteps: 206435
# episode  257 score 55.33 trailing 100 games avg -14.322 timesteps: 207435
# episode  258 score 41.00 trailing 100 games avg -13.482 timesteps: 208435
# episode  259 score 101.36 trailing 100 games avg -12.280 timesteps: 209435
# episode  260 score 94.59 trailing 10 games avg 36.097 timesteps: 210435
# episode  260 score 94.59 trailing 100 games avg -11.438 timesteps: 210435
# episode  261 score -186.08 trailing 100 games avg -13.445 timesteps: 210639
# episode  262 score 75.02 trailing 100 games avg -12.738 timesteps: 211639
# episode  263 score 50.05 trailing 100 games avg -11.846 timesteps: 212639
# episode  264 score 79.37 trailing 100 games avg -10.940 timesteps: 213639
# episode  265 score 66.76 trailing 100 games avg -10.108 timesteps: 214639
# episode  266 score 29.93 trailing 100 games avg -10.000 timesteps: 215639
# episode  267 score 3.76 trailing 100 games avg -9.548 timesteps: 216639
# episode  268 score -174.28 trailing 100 games avg -11.996 timesteps: 217134
# episode  269 score 53.63 trailing 100 games avg -11.637 timesteps: 218134
# episode  270 score -70.60 trailing 10 games avg -7.244 timesteps: 219134
# episode  270 score -70.60 trailing 100 games avg -11.860 timesteps: 219134
# episode  271 score 70.31 trailing 100 games avg -10.717 timesteps: 220134
# episode  272 score 130.52 trailing 100 games avg -8.888 timesteps: 221134
# episode  273 score 46.88 trailing 100 games avg -8.325 timesteps: 222134
# episode  274 score 85.36 trailing 100 games avg -7.405 timesteps: 223134
# episode  275 score -31.47 trailing 100 games avg -7.287 timesteps: 224134
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.45
# --------------------------------------------------------------------------------------------
# episode  276 score 15.90 trailing 100 games avg -6.551 timesteps: 225134
# episode  277 score -40.72 trailing 100 games avg -6.451 timesteps: 226134
# episode  278 score 101.68 trailing 100 games avg -4.924 timesteps: 227134
# episode  279 score -33.69 trailing 100 games avg -4.945 timesteps: 228134
# episode  280 score -104.83 trailing 10 games avg 23.994 timesteps: 229134
# episode  280 score -104.83 trailing 100 games avg -5.957 timesteps: 229134
# episode  281 score -23.73 trailing 100 games avg -5.792 timesteps: 230134
# episode  282 score -49.93 trailing 100 games avg -5.893 timesteps: 231134
# episode  283 score -53.11 trailing 100 games avg -6.132 timesteps: 232134
# episode  284 score 0.78 trailing 100 games avg -5.583 timesteps: 233134
# episode  285 score -66.55 trailing 100 games avg -4.325 timesteps: 234134
# episode  286 score 73.73 trailing 100 games avg -3.745 timesteps: 235134
# episode  287 score -73.78 trailing 100 games avg -4.413 timesteps: 236134
# episode  288 score -52.07 trailing 100 games avg -5.185 timesteps: 237134
# episode  289 score 41.78 trailing 100 games avg -4.718 timesteps: 238134
# episode  290 score -31.94 trailing 10 games avg -23.481 timesteps: 239134
# episode  290 score -31.94 trailing 100 games avg -4.607 timesteps: 239134
# episode  291 score -91.07 trailing 100 games avg -5.120 timesteps: 239697
# episode  292 score -78.43 trailing 100 games avg -5.987 timesteps: 240697
# episode  293 score -47.85 trailing 100 games avg -6.295 timesteps: 241697
# episode  294 score 91.54 trailing 100 games avg -6.254 timesteps: 242697
# episode  295 score -65.56 trailing 100 games avg -6.615 timesteps: 243697
# episode  296 score -9.65 trailing 100 games avg -6.955 timesteps: 244697
# episode  297 score 124.60 trailing 100 games avg -5.800 timesteps: 245697
# episode  298 score -71.09 trailing 100 games avg -5.921 timesteps: 246697
# episode  299 score -61.32 trailing 100 games avg -6.024 timesteps: 247697
# episode  300 score -139.50 trailing 10 games avg -34.833 timesteps: 247958
# episode  300 score -139.50 trailing 100 games avg -6.569 timesteps: 247958
# episode  301 score 38.92 trailing 100 games avg -5.837 timesteps: 248958
# episode  302 score -61.60 trailing 100 games avg -6.072 timesteps: 249958
# episode  303 score -187.29 trailing 100 games avg -7.709 timesteps: 250654
# episode  304 score -15.19 trailing 100 games avg -8.312 timesteps: 251654
# episode  305 score 100.79 trailing 100 games avg -7.273 timesteps: 252654
# episode  306 score 83.25 trailing 100 games avg -7.802 timesteps: 253654
# episode  307 score -91.09 trailing 100 games avg -7.996 timesteps: 254654
# episode  308 score -44.23 trailing 100 games avg -8.371 timesteps: 255654
# episode  309 score 65.03 trailing 100 games avg -7.412 timesteps: 256654
# episode  310 score -92.69 trailing 10 games avg -20.411 timesteps: 257654
# episode  310 score -92.69 trailing 100 games avg -8.657 timesteps: 257654
# episode  311 score -20.95 trailing 100 games avg -9.974 timesteps: 258654
# episode  312 score 88.89 trailing 100 games avg -10.320 timesteps: 259654
# episode  313 score 63.02 trailing 100 games avg -10.503 timesteps: 260654
# episode  314 score 131.88 trailing 100 games avg -9.580 timesteps: 261654
# episode  315 score 106.32 trailing 100 games avg -7.596 timesteps: 262654
# episode  316 score 98.91 trailing 100 games avg -7.101 timesteps: 263654
# episode  317 score 87.35 trailing 100 games avg -5.851 timesteps: 264654
# episode  318 score -0.79 trailing 100 games avg -5.600 timesteps: 265654
# episode  319 score -43.48 trailing 100 games avg -5.951 timesteps: 266654
# episode  320 score 4.44 trailing 10 games avg 51.560 timesteps: 267654
# episode  320 score 4.44 trailing 100 games avg -6.059 timesteps: 267654
# episode  321 score 78.40 trailing 100 games avg -5.590 timesteps: 268654
# episode  322 score 60.04 trailing 100 games avg -5.561 timesteps: 269654
# episode  323 score 60.54 trailing 100 games avg -5.599 timesteps: 270654
# episode  324 score 99.41 trailing 100 games avg -5.358 timesteps: 271654
# episode  325 score 67.01 trailing 100 games avg -5.151 timesteps: 272654
# episode  326 score 70.14 trailing 100 games avg -4.446 timesteps: 273654
# episode  327 score 39.31 trailing 100 games avg -4.538 timesteps: 274654
# episode  328 score 78.65 trailing 100 games avg -4.283 timesteps: 275654
# episode  329 score -2.27 trailing 100 games avg -5.180 timesteps: 276654
# episode  330 score 57.65 trailing 10 games avg 60.888 timesteps: 277654
# episode  330 score 57.65 trailing 100 games avg -0.742 timesteps: 277654
# episode  331 score 13.65 trailing 100 games avg -1.174 timesteps: 278654
# episode  332 score -303.01 trailing 100 games avg -2.474 timesteps: 279654
# episode  333 score 38.31 trailing 100 games avg -1.061 timesteps: 280654
# episode  334 score 95.63 trailing 100 games avg 0.719 timesteps: 281364
# episode  335 score 139.24 trailing 100 games avg 1.477 timesteps: 282364
# episode  336 score 91.57 trailing 100 games avg 2.940 timesteps: 283364
# episode  337 score 101.44 trailing 100 games avg 4.092 timesteps: 284364
# episode  338 score -7.32 trailing 100 games avg 6.612 timesteps: 285364
# episode  339 score 39.13 trailing 100 games avg 8.668 timesteps: 286364
# episode  340 score 63.81 trailing 10 games avg 27.245 timesteps: 287364
# episode  340 score 63.81 trailing 100 games avg 10.573 timesteps: 287364
# episode  341 score 173.22 trailing 100 games avg 14.063 timesteps: 288250
# episode  342 score -55.77 trailing 100 games avg 13.336 timesteps: 288649
# episode  343 score 178.42 trailing 100 games avg 14.308 timesteps: 289260
# episode  344 score 101.42 trailing 100 games avg 14.123 timesteps: 290260
# episode  345 score 110.66 trailing 100 games avg 15.286 timesteps: 291260
# episode  346 score 117.57 trailing 100 games avg 16.136 timesteps: 292114
# episode  347 score 109.80 trailing 100 games avg 19.267 timesteps: 293114
# episode  348 score 98.17 trailing 100 games avg 20.259 timesteps: 294114
# episode  349 score 120.65 trailing 100 games avg 21.457 timesteps: 295114
# episode  350 score 21.41 trailing 10 games avg 97.555 timesteps: 296114
# episode  350 score 21.41 trailing 100 games avg 21.137 timesteps: 296114
# episode  351 score -1.25 trailing 100 games avg 20.732 timesteps: 297114
# episode  352 score -16.49 trailing 100 games avg 19.184 timesteps: 298114
# episode  353 score -84.04 trailing 100 games avg 17.692 timesteps: 298907
# episode  354 score 1.68 trailing 100 games avg 18.924 timesteps: 299907
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.4
# --------------------------------------------------------------------------------------------
# episode  355 score 161.01 trailing 100 games avg 21.726 timesteps: 300701
# episode  356 score 0.29 trailing 100 games avg 21.062 timesteps: 301701
# episode  357 score 212.63 trailing 100 games avg 22.635 timesteps: 302459
# episode  358 score 134.26 trailing 100 games avg 23.567 timesteps: 303459
# episode  359 score 118.56 trailing 100 games avg 23.740 timesteps: 304459
# episode  360 score 6.15 trailing 10 games avg 53.279 timesteps: 305459
# episode  360 score 6.15 trailing 100 games avg 22.855 timesteps: 305459
# episode  361 score 71.16 trailing 100 games avg 25.428 timesteps: 306459
# episode  362 score 79.33 trailing 100 games avg 25.471 timesteps: 307459
# episode  363 score 97.23 trailing 100 games avg 25.942 timesteps: 308459
# episode  364 score -87.81 trailing 100 games avg 24.271 timesteps: 308919
# episode  365 score 224.85 trailing 100 games avg 25.852 timesteps: 309630
# episode  366 score 122.58 trailing 100 games avg 26.778 timesteps: 310545
# episode  367 score -8.32 trailing 100 games avg 26.657 timesteps: 311545
# episode  368 score 151.25 trailing 100 games avg 29.913 timesteps: 312391
# episode  369 score 105.60 trailing 100 games avg 30.432 timesteps: 313391
# episode  370 score 15.95 trailing 10 games avg 77.183 timesteps: 314391
# episode  370 score 15.95 trailing 100 games avg 31.298 timesteps: 314391
# episode  371 score -14.30 trailing 100 games avg 30.452 timesteps: 315391
# episode  372 score 264.21 trailing 100 games avg 31.789 timesteps: 315831
# episode  373 score -182.71 trailing 100 games avg 29.493 timesteps: 316708
# episode  374 score 60.83 trailing 100 games avg 29.247 timesteps: 317708
# episode  375 score 147.22 trailing 100 games avg 31.034 timesteps: 318448
# episode  376 score 71.80 trailing 100 games avg 31.593 timesteps: 319448
# episode  377 score 53.95 trailing 100 games avg 32.540 timesteps: 320448
# episode  378 score 128.22 trailing 100 games avg 32.805 timesteps: 321448
# episode  379 score 257.62 trailing 100 games avg 35.719 timesteps: 322240
# episode  380 score 133.51 trailing 10 games avg 92.036 timesteps: 323240
# episode  380 score 133.51 trailing 100 games avg 38.102 timesteps: 323240
# episode  381 score 251.17 trailing 100 games avg 40.851 timesteps: 323734
# episode  382 score 172.85 trailing 100 games avg 43.079 timesteps: 324734
# episode  383 score 157.98 trailing 100 games avg 45.190 timesteps: 325402
# episode  384 score 123.11 trailing 100 games avg 46.413 timesteps: 326402
# episode  385 score 196.64 trailing 100 games avg 49.045 timesteps: 326926
# episode  386 score 93.29 trailing 100 games avg 49.241 timesteps: 327926
# episode  387 score 104.84 trailing 100 games avg 51.027 timesteps: 328926
# episode  388 score 6.07 trailing 100 games avg 51.608 timesteps: 329926
# episode  389 score 154.70 trailing 100 games avg 52.737 timesteps: 330926
# episode  390 score 281.87 trailing 10 games avg 154.252 timesteps: 331336
# episode  390 score 281.87 trailing 100 games avg 55.875 timesteps: 331336
# episode  391 score 150.82 trailing 100 games avg 58.294 timesteps: 332336
# episode  392 score 243.67 trailing 100 games avg 61.515 timesteps: 332819
# episode  393 score 254.47 trailing 100 games avg 64.538 timesteps: 333212
# episode  394 score 112.65 trailing 100 games avg 64.750 timesteps: 334212
# episode  395 score 135.26 trailing 100 games avg 66.758 timesteps: 335212
# episode  396 score 178.29 trailing 100 games avg 68.637 timesteps: 335963
# episode  397 score 243.13 trailing 100 games avg 69.822 timesteps: 336344
# episode  398 score 164.99 trailing 100 games avg 72.183 timesteps: 337344
# episode  399 score 103.41 trailing 100 games avg 73.830 timesteps: 338344
# episode  400 score 258.83 trailing 10 games avg 184.551 timesteps: 338609
# episode  400 score 258.83 trailing 100 games avg 77.814 timesteps: 338609
# episode  401 score 264.53 trailing 100 games avg 80.070 timesteps: 339510
# episode  402 score 270.01 trailing 100 games avg 83.386 timesteps: 339960
# episode  403 score 131.05 trailing 100 games avg 86.570 timesteps: 340960
# episode  404 score 236.19 trailing 100 games avg 89.083 timesteps: 341658
# episode  405 score 272.23 trailing 100 games avg 90.798 timesteps: 342148
# episode  406 score 109.71 trailing 100 games avg 91.062 timesteps: 343148
# episode  407 score 170.98 trailing 100 games avg 93.683 timesteps: 344148
# episode  408 score 147.34 trailing 100 games avg 95.599 timesteps: 345148
# episode  409 score 259.27 trailing 100 games avg 97.541 timesteps: 345985
# episode  410 score 150.77 trailing 10 games avg 201.208 timesteps: 346985
# episode  410 score 150.77 trailing 100 games avg 99.976 timesteps: 346985
# episode  411 score 235.29 trailing 100 games avg 102.538 timesteps: 347310
# episode  412 score 254.00 trailing 100 games avg 104.189 timesteps: 347867
# episode  413 score 175.83 trailing 100 games avg 105.317 timesteps: 348867
# episode  414 score 141.13 trailing 100 games avg 105.410 timesteps: 349867
# episode  415 score 280.66 trailing 100 games avg 107.153 timesteps: 350675
# episode  416 score 108.51 trailing 100 games avg 107.249 timesteps: 351675
# episode  417 score 250.67 trailing 100 games avg 108.882 timesteps: 352507
# episode  418 score 149.70 trailing 100 games avg 110.387 timesteps: 353507
# episode  419 score 245.63 trailing 100 games avg 113.278 timesteps: 353982
# episode  420 score 140.24 trailing 10 games avg 198.165 timesteps: 354982
# episode  420 score 140.24 trailing 100 games avg 114.636 timesteps: 354982
# episode  421 score 209.23 trailing 100 games avg 115.944 timesteps: 355730
# episode  422 score 111.76 trailing 100 games avg 116.462 timesteps: 356730
# episode  423 score 240.77 trailing 100 games avg 118.264 timesteps: 357711
# episode  424 score 125.10 trailing 100 games avg 118.521 timesteps: 358711
# episode  425 score 153.92 trailing 100 games avg 119.390 timesteps: 359711
# episode  426 score 156.57 trailing 100 games avg 120.254 timesteps: 360711
# episode  427 score 252.03 trailing 100 games avg 122.382 timesteps: 361564
# episode  428 score 130.87 trailing 100 games avg 122.904 timesteps: 362564
# episode  429 score 272.56 trailing 100 games avg 125.652 timesteps: 363141
# episode  430 score 218.23 trailing 10 games avg 187.105 timesteps: 363662
# episode  430 score 218.23 trailing 100 games avg 127.258 timesteps: 363662
# episode  431 score 111.35 trailing 100 games avg 128.235 timesteps: 364662
# episode  432 score 128.06 trailing 100 games avg 132.546 timesteps: 365662
# episode  433 score 194.11 trailing 100 games avg 134.103 timesteps: 366349
# episode  434 score 115.02 trailing 100 games avg 134.297 timesteps: 367349
# episode  435 score 256.79 trailing 100 games avg 135.473 timesteps: 367722
# episode  436 score 146.48 trailing 100 games avg 136.022 timesteps: 368722
# episode  437 score 245.59 trailing 100 games avg 137.464 timesteps: 369671
# episode  438 score 116.84 trailing 100 games avg 138.705 timesteps: 370671
# episode  439 score 269.36 trailing 100 games avg 141.007 timesteps: 371050
# episode  440 score 92.16 trailing 10 games avg 167.576 timesteps: 372050
# episode  440 score 92.16 trailing 100 games avg 141.291 timesteps: 372050
# episode  441 score 249.64 trailing 100 games avg 142.055 timesteps: 372546
# episode  442 score 86.73 trailing 100 games avg 143.480 timesteps: 373546
# episode  443 score 142.12 trailing 100 games avg 143.117 timesteps: 374546
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.35
# --------------------------------------------------------------------------------------------
# episode  444 score 146.75 trailing 100 games avg 143.570 timesteps: 375546
# episode  445 score 248.50 trailing 100 games avg 144.949 timesteps: 376012
# episode  446 score 115.92 trailing 100 games avg 144.932 timesteps: 377012
# episode  447 score 131.02 trailing 100 games avg 145.145 timesteps: 378012
# episode  448 score 140.73 trailing 100 games avg 145.570 timesteps: 379012
# episode  449 score 115.78 trailing 100 games avg 145.522 timesteps: 380012
# episode  450 score 221.63 trailing 10 games avg 159.883 timesteps: 380806
# episode  450 score 221.63 trailing 100 games avg 147.524 timesteps: 380806
# episode  451 score 218.05 trailing 100 games avg 149.717 timesteps: 381407
# episode  452 score 121.17 trailing 100 games avg 151.093 timesteps: 382407
# episode  453 score 147.33 trailing 100 games avg 153.407 timesteps: 383407
# episode  454 score 218.23 trailing 100 games avg 155.573 timesteps: 384030
# episode  455 score 267.84 trailing 100 games avg 156.641 timesteps: 384926
# episode  456 score 231.27 trailing 100 games avg 158.951 timesteps: 385239
# episode  457 score 116.03 trailing 100 games avg 157.985 timesteps: 386239
# episode  458 score 120.66 trailing 100 games avg 157.849 timesteps: 387239
# episode  459 score 255.90 trailing 100 games avg 159.222 timesteps: 387665
# episode  460 score 226.91 trailing 10 games avg 192.338 timesteps: 388264
# episode  460 score 226.91 trailing 100 games avg 161.430 timesteps: 388264
# episode  461 score 217.61 trailing 100 games avg 162.894 timesteps: 389143
# episode  462 score 303.50 trailing 100 games avg 165.136 timesteps: 389431
# episode  463 score 162.76 trailing 100 games avg 165.791 timesteps: 389830
# episode  464 score 222.34 trailing 100 games avg 168.893 timesteps: 390229
# episode  465 score 279.95 trailing 100 games avg 169.444 timesteps: 390931
# episode  466 score 215.24 trailing 100 games avg 170.370 timesteps: 391561
# episode  467 score -6.35 trailing 100 games avg 170.390 timesteps: 392561
# episode  468 score 198.84 trailing 100 games avg 170.866 timesteps: 393432
# episode  469 score 232.34 trailing 100 games avg 172.133 timesteps: 394341
# episode  470 score 91.94 trailing 10 games avg 191.816 timesteps: 395341
# episode  470 score 91.94 trailing 100 games avg 172.893 timesteps: 395341
# episode  471 score 94.62 trailing 100 games avg 173.982 timesteps: 396341
# episode  472 score 152.90 trailing 100 games avg 172.869 timesteps: 397341
# episode  473 score 120.17 trailing 100 games avg 175.898 timesteps: 398341
# episode  474 score 196.56 trailing 100 games avg 177.255 timesteps: 398727
# episode  475 score 141.78 trailing 100 games avg 177.201 timesteps: 399727
# episode  476 score 239.22 trailing 100 games avg 178.875 timesteps: 400634
# episode  477 score 122.52 trailing 100 games avg 179.561 timesteps: 401634
# episode  478 score 240.83 trailing 100 games avg 180.687 timesteps: 402253
# episode  479 score 113.03 trailing 100 games avg 179.241 timesteps: 403253
# episode  480 score 113.96 trailing 10 games avg 153.559 timesteps: 404253
# episode  480 score 113.96 trailing 100 games avg 179.045 timesteps: 404253
# episode  481 score 258.31 trailing 100 games avg 179.117 timesteps: 404826
# episode  482 score 228.85 trailing 100 games avg 179.677 timesteps: 405144
# episode  483 score 150.99 trailing 100 games avg 179.607 timesteps: 406144
# episode  484 score 147.35 trailing 100 games avg 179.849 timesteps: 407144
# episode  485 score 232.26 trailing 100 games avg 180.205 timesteps: 407521
# episode  486 score 83.56 trailing 100 games avg 180.108 timesteps: 408521
# episode  487 score 124.97 trailing 100 games avg 180.309 timesteps: 409521
# episode  488 score 92.26 trailing 100 games avg 181.171 timesteps: 410521
# episode  489 score 206.65 trailing 100 games avg 181.691 timesteps: 411069
# episode  490 score 218.36 trailing 10 games avg 174.356 timesteps: 411679
# episode  490 score 218.36 trailing 100 games avg 181.056 timesteps: 411679
# episode  491 score 256.26 trailing 100 games avg 182.110 timesteps: 412074
# episode  492 score 187.12 trailing 100 games avg 181.545 timesteps: 412544
# episode  493 score 243.99 trailing 100 games avg 181.440 timesteps: 413007
# episode  494 score 258.16 trailing 100 games avg 182.895 timesteps: 413936
# episode  495 score 254.20 trailing 100 games avg 184.084 timesteps: 414532
# episode  496 score 85.99 trailing 100 games avg 183.161 timesteps: 415532
# episode  497 score 103.25 trailing 100 games avg 181.763 timesteps: 416532
# episode  498 score 244.91 trailing 100 games avg 182.562 timesteps: 416951
# episode  499 score 243.90 trailing 100 games avg 183.967 timesteps: 417426
# episode  500 score 193.45 trailing 10 games avg 207.123 timesteps: 417874
# episode  500 score 193.45 trailing 100 games avg 183.313 timesteps: 417874
# episode  501 score 249.75 trailing 100 games avg 183.165 timesteps: 418543
# episode  502 score 155.97 trailing 100 games avg 182.025 timesteps: 419543
# episode  503 score 93.20 trailing 100 games avg 181.646 timesteps: 420543
# episode  504 score 255.62 trailing 100 games avg 181.840 timesteps: 420941
# episode  505 score 265.11 trailing 100 games avg 181.769 timesteps: 421306
# episode  506 score 104.92 trailing 100 games avg 181.721 timesteps: 422306
# episode  507 score 237.29 trailing 100 games avg 182.384 timesteps: 423132
# episode  508 score 226.11 trailing 100 games avg 183.172 timesteps: 423743
# episode  509 score 57.17 trailing 100 games avg 181.151 timesteps: 424743
# episode  510 score 118.30 trailing 10 games avg 176.345 timesteps: 425743
# episode  510 score 118.30 trailing 100 games avg 180.827 timesteps: 425743
# episode  511 score 243.65 trailing 100 games avg 180.910 timesteps: 426128
# episode  512 score 130.97 trailing 100 games avg 179.680 timesteps: 427128
# episode  513 score 246.25 trailing 100 games avg 180.384 timesteps: 427481
# episode  514 score 185.50 trailing 100 games avg 180.828 timesteps: 428140
# episode  515 score 129.67 trailing 100 games avg 179.318 timesteps: 429140
# episode  516 score 224.79 trailing 100 games avg 180.481 timesteps: 429483
# episode  517 score 251.57 trailing 100 games avg 180.490 timesteps: 429935
# episode  518 score 259.13 trailing 100 games avg 181.584 timesteps: 430422
# episode  519 score 136.94 trailing 100 games avg 180.497 timesteps: 431422
# episode  520 score -32.76 trailing 10 games avg 177.569 timesteps: 431665
# episode  520 score -32.76 trailing 100 games avg 178.767 timesteps: 431665
# episode  521 score 214.27 trailing 100 games avg 178.817 timesteps: 432354
# episode  522 score 269.10 trailing 100 games avg 180.391 timesteps: 433179
# episode  523 score 209.58 trailing 100 games avg 180.079 timesteps: 434093
# episode  524 score 73.08 trailing 100 games avg 179.559 timesteps: 435093
# episode  525 score 88.93 trailing 100 games avg 178.909 timesteps: 436093
# episode  526 score 255.25 trailing 100 games avg 179.895 timesteps: 436519
# episode  527 score 267.45 trailing 100 games avg 180.050 timesteps: 436809
# episode  528 score 276.58 trailing 100 games avg 181.507 timesteps: 437115
# episode  529 score 186.67 trailing 100 games avg 180.648 timesteps: 437962
# episode  530 score 268.26 trailing 10 games avg 210.918 timesteps: 438355
# episode  530 score 268.26 trailing 100 games avg 181.148 timesteps: 438355
# episode  531 score 32.90 trailing 100 games avg 180.364 timesteps: 438453
# episode  532 score 113.59 trailing 100 games avg 180.219 timesteps: 439453
# episode  533 score 235.65 trailing 100 games avg 180.634 timesteps: 440136
# episode  534 score 265.55 trailing 100 games avg 182.140 timesteps: 440991
# episode  535 score 199.79 trailing 100 games avg 181.570 timesteps: 441607
# episode  536 score 223.09 trailing 100 games avg 182.336 timesteps: 442111
# episode  537 score 159.95 trailing 100 games avg 181.479 timesteps: 443111
# episode  538 score 258.99 trailing 100 games avg 182.901 timesteps: 443793
# episode  539 score 297.93 trailing 100 games avg 183.187 timesteps: 444157
# episode  540 score 263.84 trailing 10 games avg 205.127 timesteps: 444514
# episode  540 score 263.84 trailing 100 games avg 184.903 timesteps: 444514
# episode  541 score 271.79 trailing 100 games avg 185.125 timesteps: 445079
# episode  542 score 223.78 trailing 100 games avg 186.495 timesteps: 446050
# episode  543 score 11.92 trailing 100 games avg 185.193 timesteps: 446256
# episode  544 score 68.97 trailing 100 games avg 184.416 timesteps: 447256
# episode  545 score 172.45 trailing 100 games avg 183.655 timesteps: 447924
# episode  546 score 194.47 trailing 100 games avg 184.441 timesteps: 448655
# episode  547 score 112.46 trailing 100 games avg 184.255 timesteps: 449655
# episode  548 score 248.89 trailing 100 games avg 185.337 timesteps: 449989
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.3
# --------------------------------------------------------------------------------------------
# episode  549 score 130.29 trailing 100 games avg 185.482 timesteps: 450613
# episode  550 score 244.87 trailing 10 games avg 167.989 timesteps: 451067
# episode  550 score 244.87 trailing 100 games avg 185.714 timesteps: 451067
# episode  551 score 66.77 trailing 100 games avg 184.201 timesteps: 452067
# episode  552 score 227.36 trailing 100 games avg 185.263 timesteps: 452853
# episode  553 score 207.57 trailing 100 games avg 185.866 timesteps: 453293
# episode  554 score 274.32 trailing 100 games avg 186.427 timesteps: 453613
# episode  555 score 234.24 trailing 100 games avg 186.091 timesteps: 454195
# episode  556 score 216.83 trailing 100 games avg 185.946 timesteps: 454521
# episode  557 score 223.83 trailing 100 games avg 187.024 timesteps: 454844
# episode  558 score 220.77 trailing 100 games avg 188.025 timesteps: 455243
# episode  559 score 168.20 trailing 100 games avg 187.148 timesteps: 455606
# episode  560 score 262.30 trailing 10 games avg 210.220 timesteps: 455940
# episode  560 score 262.30 trailing 100 games avg 187.502 timesteps: 455940
# episode  561 score 248.67 trailing 100 games avg 187.813 timesteps: 456387
# episode  562 score 190.23 trailing 100 games avg 186.680 timesteps: 456845
# episode  563 score 252.38 trailing 100 games avg 187.576 timesteps: 457332
# episode  564 score 242.90 trailing 100 games avg 187.782 timesteps: 457691
# episode  565 score 233.44 trailing 100 games avg 187.317 timesteps: 457977
# episode  566 score 206.49 trailing 100 games avg 187.230 timesteps: 458491
# episode  567 score 160.07 trailing 100 games avg 188.894 timesteps: 459048
# episode  568 score 242.14 trailing 100 games avg 189.327 timesteps: 459659
# episode  569 score 253.21 trailing 100 games avg 189.535 timesteps: 460022
# episode  570 score 251.68 trailing 10 games avg 228.122 timesteps: 460320
# episode  570 score 251.68 trailing 100 games avg 191.133 timesteps: 460320
# episode  571 score 128.06 trailing 100 games avg 191.467 timesteps: 461320
# episode  572 score 147.76 trailing 100 games avg 191.416 timesteps: 462320
# episode  573 score 249.91 trailing 100 games avg 192.713 timesteps: 462874
# episode  574 score 141.32 trailing 100 games avg 192.161 timesteps: 463874
# episode  575 score -136.53 trailing 100 games avg 189.378 timesteps: 463983
# episode  576 score 238.39 trailing 100 games avg 189.370 timesteps: 464289
# episode  577 score 14.40 trailing 100 games avg 188.288 timesteps: 465289
# episode  578 score -54.27 trailing 100 games avg 185.337 timesteps: 466289
# episode  579 score 249.42 trailing 100 games avg 186.701 timesteps: 466589
# episode  580 score 247.67 trailing 10 games avg 122.613 timesteps: 466932
# episode  580 score 247.67 trailing 100 games avg 188.038 timesteps: 466932
# episode  581 score 94.48 trailing 100 games avg 186.400 timesteps: 467932
# episode  582 score 214.63 trailing 100 games avg 186.258 timesteps: 468449
# episode  583 score -3.94 trailing 100 games avg 184.708 timesteps: 469449
# episode  584 score -100.50 trailing 100 games avg 182.230 timesteps: 469583
# episode  585 score 230.92 trailing 100 games avg 182.217 timesteps: 470066
# episode  586 score 245.79 trailing 100 games avg 183.839 timesteps: 470441
# episode  587 score 250.25 trailing 100 games avg 185.092 timesteps: 470810
# episode  588 score 240.40 trailing 100 games avg 186.573 timesteps: 471176
# episode  589 score -26.34 trailing 100 games avg 184.243 timesteps: 471292
# episode  590 score 275.52 trailing 10 games avg 142.120 timesteps: 471669
# episode  590 score 275.52 trailing 100 games avg 184.815 timesteps: 471669
# episode  591 score 255.18 trailing 100 games avg 184.804 timesteps: 472035
# episode  592 score 290.42 trailing 100 games avg 185.837 timesteps: 472254
# episode  593 score 269.07 trailing 100 games avg 186.088 timesteps: 472581
# episode  594 score 231.09 trailing 100 games avg 185.817 timesteps: 472975
# episode  595 score 262.17 trailing 100 games avg 185.897 timesteps: 473332
# episode  596 score 224.56 trailing 100 games avg 187.282 timesteps: 473742
# episode  597 score 235.70 trailing 100 games avg 188.607 timesteps: 474154
# episode  598 score 248.64 trailing 100 games avg 188.644 timesteps: 474626
# episode  599 score 175.87 trailing 100 games avg 187.964 timesteps: 475125
# episode  600 score 252.69 trailing 10 games avg 244.540 timesteps: 475677
# episode  600 score 252.69 trailing 100 games avg 188.556 timesteps: 475677
# episode  601 score 252.28 trailing 100 games avg 188.582 timesteps: 476172
# episode  602 score 53.45 trailing 100 games avg 187.556 timesteps: 477172
# episode  603 score 219.23 trailing 100 games avg 188.817 timesteps: 477505
# episode  604 score 210.99 trailing 100 games avg 188.370 timesteps: 477813
# episode  605 score 246.88 trailing 100 games avg 188.188 timesteps: 478105
# episode  606 score 242.03 trailing 100 games avg 189.559 timesteps: 478676
# episode  607 score 281.86 trailing 100 games avg 190.005 timesteps: 479067
# episode  608 score 240.94 trailing 100 games avg 190.153 timesteps: 479462
# episode  609 score 223.35 trailing 100 games avg 191.815 timesteps: 480001
# episode  610 score 258.55 trailing 10 games avg 222.956 timesteps: 480815
# episode  610 score 258.55 trailing 100 games avg 193.217 timesteps: 480815
# episode  611 score 230.99 trailing 100 games avg 193.091 timesteps: 481146
# episode  612 score 205.85 trailing 100 games avg 193.840 timesteps: 481442
# episode  613 score 230.14 trailing 100 games avg 193.679 timesteps: 482411
# episode  614 score 237.20 trailing 100 games avg 194.196 timesteps: 482885
# episode  615 score 278.22 trailing 100 games avg 195.681 timesteps: 483228
# episode  616 score 219.01 trailing 100 games avg 195.623 timesteps: 483611
# episode  617 score 253.21 trailing 100 games avg 195.640 timesteps: 484215
# episode  618 score 102.78 trailing 100 games avg 194.076 timesteps: 485215
# episode  619 score 235.74 trailing 100 games avg 195.064 timesteps: 485592
# episode  620 score 278.51 trailing 10 games avg 227.164 timesteps: 485980
# episode  620 score 278.51 trailing 100 games avg 198.177 timesteps: 485980
# episode  621 score 231.10 trailing 100 games avg 198.345 timesteps: 486432
# episode  622 score 220.62 trailing 100 games avg 197.860 timesteps: 486951
# episode  623 score -5.17 trailing 100 games avg 195.713 timesteps: 487951
# episode  624 score 259.26 trailing 100 games avg 197.575 timesteps: 488329
# episode  625 score 217.01 trailing 100 games avg 198.855 timesteps: 489106
# episode  626 score 265.64 trailing 100 games avg 198.959 timesteps: 489732
# episode  627 score 253.62 trailing 100 games avg 198.821 timesteps: 489961
# episode  628 score 203.73 trailing 100 games avg 198.092 timesteps: 490595
# episode  629 score 281.53 trailing 100 games avg 199.041 timesteps: 490912
# episode  630 score 253.78 trailing 10 games avg 218.111 timesteps: 491202
# episode  630 score 253.78 trailing 100 games avg 198.896 timesteps: 491202
# episode  631 score 228.78 trailing 100 games avg 200.855 timesteps: 491507
# episode  632 score 240.26 trailing 100 games avg 202.122 timesteps: 491993
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-afbff0f3786f> in <module>()
#      18     while not done:
#      19         act = agent.choose_action(obs)
# ---> 20         new_state, reward, done, info = env.step(act)
#      21         agent.remember(obs, act, reward, new_state, int(done))
#      22         agent.learn()
#
# /usr/local/lib/python3.7/dist-packages/gym/wrappers/time_limit.py in step(self, action)
#      14     def step(self, action):
#      15         assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16         observation, reward, done, info = self.env.step(action)
#      17         self._elapsed_steps += 1
#      18         if self._elapsed_steps >= self._max_episode_steps:
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/box2d/lunar_lander.py in step(self, action)
#     246     def step(self, action):
#     247         if self.continuous:
# --> 248             action = np.clip(action, -1, +1).astype(np.float32)
#     249         else:
#     250             assert self.action_space.contains(action), "%r (%s) invalid " % (action, type(action))
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2095
#    2096     """
# -> 2097     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2098
#    2099
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     139     else:
#     140         return _clip_dep_invoke_with_casting(
# --> 141             um.clip, a, min, max, out=out, casting=casting, **kwargs)
#     142
#     143 def _mean(a, axis=None, dtype=None, out=None, keepdims=False):
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py in _clip_dep_invoke_with_casting(ufunc, out, casting, *args, **kwargs)
#      92     # try to deal with broken casting rules
#      93     try:
# ---> 94         return ufunc(*args, out=out, **kwargs)
#      95     except _exceptions._UFuncOutputCastingError as e:
#      96         # Numpy 1.17.0, 2019-02-24
#
# KeyboardInterrupt:

# %%
####Mine

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as Optim
import numpy as np
from torch.distributions import MultivariateNormal

class Actor(nn.Module):
  def __init__(self,input_dims,fc1_dims,fc2_dims,action_dims,device):
    super(Actor,self).__init__()

    self.fc1 = nn.Linear(input_dims,fc1_dims)
    f1 = 1 / np.sqrt(self.fc1.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
    torch.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
    self.bn1 = nn.LayerNorm(fc1_dims)

    self.fc2 = nn.Linear(fc1_dims,fc2_dims)
    f2 = 1 / np.sqrt(self.fc2.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
    torch.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
    self.bn2 = nn.LayerNorm(fc2_dims)

    f3 = 0.003
    self.mu = nn.Linear(fc2_dims,action_dims)
    torch.nn.init.uniform_(self.mu.weight.data, -f3, f3)
    torch.nn.init.uniform_(self.mu.bias.data, -f3, f3)

    self.device = device
    self.to(self.device)
  
  def forward(self,state):

    x = F.relu(self.bn1(self.fc1(state)))
    x = F.relu(self.bn2(self.fc2(x)))

    action_mu = torch.tanh(self.mu(x))

    return action_mu


class Critic(nn.Module):
  def __init__(self,input_dims,fc1_dims,fc2_dims,action_dims,device):
    super(Critic,self).__init__()

    self.fc1 = nn.Linear(input_dims,fc1_dims)
    f1 = 1 / np.sqrt(self.fc1.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc1.weight.data, -f1, f1)
    torch.nn.init.uniform_(self.fc1.bias.data, -f1, f1)
    self.bn1 = nn.LayerNorm(fc1_dims)

    self.fc2 = nn.Linear(fc1_dims,fc2_dims)
    f2 = 1 / np.sqrt(self.fc2.weight.data.size()[0])
    torch.nn.init.uniform_(self.fc2.weight.data, -f2, f2)
    torch.nn.init.uniform_(self.fc2.bias.data, -f2, f2)
    self.bn2 = nn.LayerNorm(fc2_dims)

    self.action_value_layer = nn.Linear(action_dims,fc2_dims)

    f3 = 0.003
    self.q = nn.Linear(fc2_dims,1)
    torch.nn.init.uniform_(self.q.weight.data, -f3, f3)
    torch.nn.init.uniform_(self.q.bias.data, -f3, f3)

    self.device = device
    self.to(self.device)
  
  def forward(self,state,action):

    state_value = F.relu(self.bn1(self.fc1(state)))
    state_value = self.bn2(self.fc2(state_value))

    action_value = F.relu(self.action_value_layer(action))

    state_action_value = F.relu(torch.add(state_value,action_value))
    state_action_value = self.q(state_action_value)

    return state_action_value
  

class Agent:
  def __init__(self,alpha,beta,input_dims,fc1_dims,fc2_dims,action_dims,tau,env,action_std_decay_rate,device,
                 min_action_std, gamma=0.99,max_size=1000000,batch_size=64,action_std_init=0.6):
    
    self.action_dims = action_dims
    self.gamma = gamma
    self.tau = tau
    self.env = env
    self.batch_size = batch_size
    self.device = device

    self.action_dims=action_dims
    self.action_std_decay_rate = action_std_decay_rate
    self.min_action_std = min_action_std

    self.actor = Actor(input_dims=input_dims,fc1_dims=fc1_dims,fc2_dims=fc2_dims,action_dims=action_dims,device=device)
    self.target_actor = Actor(input_dims=input_dims,fc1_dims=fc1_dims,fc2_dims=fc2_dims,action_dims=action_dims,device=device)

    self.critic = Critic(input_dims=input_dims,fc1_dims=fc1_dims,fc2_dims=fc2_dims,action_dims=action_dims,device=device)
    self.target_critic = Critic(input_dims=input_dims,fc1_dims=fc1_dims,fc2_dims=fc2_dims,action_dims=action_dims,device=device)

    self.critic_optimizer = Optim.Adam(self.critic.parameters(),lr=beta)
    self.actor_optimizer = Optim.Adam(self.actor.parameters(),lr=alpha)

    self.action_std = action_std_init
    self.action_var = torch.full((self.action_dims,), self.action_std * self.action_std).to(device)

    self.mem_size = max_size
    self.mem_cntr = 0
    self.state_memory = np.zeros((self.mem_size, input_dims))
    self.new_state_memory = np.zeros((self.mem_size, input_dims))
    self.action_memory = np.zeros((self.mem_size,action_dims))
    self.reward_memory = np.zeros((self.mem_size,1))
    self.terminal_memory = np.zeros((self.mem_size,1), dtype=np.float32)

    self.update_network_parameters(tau=1)

  
  def update_network_parameters(self, tau=None):
        if tau is None:
            tau = self.tau

        actor_params = self.actor.named_parameters()
        critic_params = self.critic.named_parameters()
        target_actor_params = self.target_actor.named_parameters()
        target_critic_params = self.target_critic.named_parameters()

        critic_state_dict = dict(critic_params)
        actor_state_dict = dict(actor_params)
        target_critic_dict = dict(target_critic_params)
        target_actor_dict = dict(target_actor_params)

        for name in critic_state_dict:
            critic_state_dict[name] = tau*critic_state_dict[name].clone() + \
                                      (1-tau)*target_critic_dict[name].clone()

        self.target_critic.load_state_dict(critic_state_dict)

        for name in actor_state_dict:
            actor_state_dict[name] = tau*actor_state_dict[name].clone() + \
                                      (1-tau)*target_actor_dict[name].clone()
        self.target_actor.load_state_dict(actor_state_dict)


  
  
  def set_action_std(self, new_action_std):
    self.action_std = new_action_std
    self.action_var = torch.full((self.action_dims,), self.action_std * self.action_std).to(self.device)

  
  
  def decay_action_std(self):
    print("--------------------------------------------------------------------------------------------")
    
    self.action_std = self.action_std - self.action_std_decay_rate
    self.action_std = round(self.action_std, 4)
    if (self.action_std <= self.min_action_std):
      self.action_std = self.min_action_std
      print("setting actor output action_std to min_action_std : ", self.action_std)
      self.set_action_std(self.action_std)
    else:
      print("setting actor output action_std to : ", self.action_std)
      self.set_action_std(self.action_std)
    
    print("--------------------------------------------------------------------------------------------")

  
  def remember(self,state,action,reward,new_state,done):
    index = self.mem_cntr % self.mem_size
    self.state_memory[index] = state
    self.action_memory[index] = action
    self.reward_memory[index] = reward
    self.new_state_memory[index] = new_state
    self.terminal_memory[index] = float(1- done)
    self.mem_cntr += 1
  
  
  def choose_action(self,observation):
    self.actor.eval()
    with torch.no_grad():
      state = torch.FloatTensor(observation).to(self.actor.device)
      action_mean = self.actor.forward(state).to(self.actor.device)
      cov_mat = torch.diag(self.action_var).unsqueeze(dim=0)
      dist = MultivariateNormal(action_mean, cov_mat)
      
    action = dist.sample()
    low = self.env.action_space.low[0]
    high = self.env.action_space.high[0]
    action = torch.clamp(action,low,high)
    
    self.actor.train()
      
    return action.detach().cpu().numpy().flatten()
  

  def learn(self):

    if self.mem_cntr < self.batch_size:
      return
    else:
      max_mem = min(self.mem_cntr, self.mem_size)

      batch = np.random.choice(max_mem, self.batch_size)

      states = self.state_memory[batch]
      actions = self.action_memory[batch]
      rewards = self.reward_memory[batch]
      next_states = self.new_state_memory[batch]
      terminals = self.terminal_memory[batch]

      rewards = torch.tensor(rewards, dtype=torch.float).to(self.critic.device)
      terminals = torch.tensor(terminals).to(self.critic.device)
      next_states = torch.tensor(next_states, dtype=torch.float).to(self.critic.device)
      actions = torch.tensor(actions, dtype=torch.float).to(self.critic.device)
      states = torch.tensor(states, dtype=torch.float).to(self.critic.device)

      self.target_actor.eval()
      self.target_critic.eval()
      self.critic.eval()

      next_actions = self.target_actor.forward(next_states)
      next_critic_value = self.target_critic.forward(next_states,next_actions)
      critic_value = self.critic.forward(states,actions)

      targets = rewards + self.gamma*next_critic_value*terminals
      targets = torch.tensor(targets).to(self.critic.device)
      targets = targets.view(self.batch_size, 1)

      self.critic.train()
      self.critic_optimizer.zero_grad()
      critic_loss = F.mse_loss(targets, critic_value)
      critic_loss.backward()
      self.critic_optimizer.step()

      self.critic.eval()
      mu = self.actor.forward(states)
      self.actor.train()
      actor_loss = -self.critic.forward(states,mu)
      self.actor_optimizer.zero_grad()
      actor_loss.mean().backward()
      self.actor_optimizer.step()

      self.update_network_parameters()

# %%
import gym
import numpy as np

env = gym.make('LunarLanderContinuous-v2')
agent = Agent(alpha=0.000025, beta=00.000025, input_dims=8, tau=0.001, env=env,action_std_decay_rate=0.05,gamma=0.99,
                 min_action_std=0.05,batch_size=64, fc1_dims=400, fc2_dims=300, action_dims=2,action_std_init=0.6,device='cpu')

action_std_decay_freq = int(7.5e4) 
#action_std_decay_freq = int(2000) 

score_history = []
timesteps = 0
for i in range(5000):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        act = agent.choose_action(obs)
        new_state, reward, done, info = env.step(act)
        agent.remember(obs, act, reward, new_state, int(done))
        agent.learn()
        score += reward
        obs = new_state
        timesteps += 1
        
        if timesteps % action_std_decay_freq == 0:
            agent.decay_action_std()
            
        if done:
            break
        #env.render()
    score_history.append(score)

    if i % 10 == 0:
        print('episode ', i, 'score %.2f' % score,
          'trailing 10 games avg %.3f' % np.mean(score_history[-10:]),
          'trailing 100 games avg %.3f' % np.mean(score_history[-100:]),
          'timesteps:',timesteps)
    else:
        print('episode ', i, 'score %.2f' % score,
          'timesteps:',timesteps)
      
    avg_100 = np.mean(score_history[-100:])
    if avg_100 >= 210:
      print("####SOLVED!!####")
      break


avg_score = 0
print("")
for i in range(50):
  obs = env.reset()
  done = False
  score = 0
  while not done:
    act = agent.choose_action(obs)
    new_state, reward, done, info = env.step(act)
    obs = new_state
    score += reward
  avg_score += score
  print("Episode Reward:",score)

print("")
print(avg_score/50)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:227: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# episode  0 score -294.15 trailing 10 games avg -294.154 trailing 100 games avg -294.154 timesteps: 101
# episode  1 score -195.61 timesteps: 185
# episode  2 score -262.57 timesteps: 267
# episode  3 score -181.31 timesteps: 328
# episode  4 score -114.74 timesteps: 391
# episode  5 score -98.45 timesteps: 471
# episode  6 score -151.15 timesteps: 525
# episode  7 score -384.76 timesteps: 607
# episode  8 score -113.63 timesteps: 662
# episode  9 score -191.93 timesteps: 743
# episode  10 score -134.88 trailing 10 games avg -182.904 trailing 100 games avg -193.018 timesteps: 810
# episode  11 score -274.53 timesteps: 901
# episode  12 score -392.81 timesteps: 1041
# episode  13 score -398.20 timesteps: 1156
# episode  14 score -250.20 timesteps: 1262
# episode  15 score -218.76 timesteps: 1403
# episode  16 score -290.89 timesteps: 1616
# episode  17 score -152.73 timesteps: 1752
# episode  18 score -361.34 timesteps: 1861
# episode  19 score -248.24 timesteps: 1972
# episode  20 score -307.17 trailing 10 games avg -289.486 trailing 100 games avg -238.955 timesteps: 2143
# episode  21 score -405.46 timesteps: 2265
# episode  22 score -155.18 timesteps: 2582
# episode  23 score -163.65 timesteps: 2715
# episode  24 score -445.39 timesteps: 3009
# episode  25 score -288.21 timesteps: 3172
# episode  26 score -318.81 timesteps: 3417
# episode  27 score -417.81 timesteps: 3739
# episode  28 score -250.39 timesteps: 3976
# episode  29 score -444.81 timesteps: 4143
# episode  30 score -363.77 trailing 10 games avg -325.347 trailing 100 games avg -266.824 timesteps: 4461
# episode  31 score -321.84 timesteps: 4655
# episode  32 score -477.18 timesteps: 4931
# episode  33 score -140.88 timesteps: 5931
# episode  34 score -424.21 timesteps: 6081
# episode  35 score -163.30 timesteps: 7081
# episode  36 score -108.25 timesteps: 8081
# episode  37 score -492.85 timesteps: 8233
# episode  38 score -72.67 timesteps: 8459
# episode  39 score -157.34 timesteps: 9459
# episode  40 score -102.99 trailing 10 games avg -246.152 trailing 100 games avg -261.782 timesteps: 10459
# episode  41 score -141.48 timesteps: 11459
# episode  42 score -154.25 timesteps: 12459
# episode  43 score -141.78 timesteps: 13459
# --------------------------------------------------------------------------------------------
# setting actor output action_std to :  0.55
# --------------------------------------------------------------------------------------------
# episode  108 score 11.32 timesteps: 75135
# episode  109 score -3.13 timesteps: 76135
# episode  110 score 36.62 trailing 10 games avg -16.421 trailing 100 games avg -124.885 timesteps: 77135
# episode  111 score -29.38 timesteps: 78135
# episode  112 score -30.03 timesteps: 79135
# episode  113 score -32.84 timesteps: 80135
# episode  114 score -35.77 timesteps: 81135
# episode  115 score 30.82 timesteps: 82135
# episode  116 score -65.75 timesteps: 83135
# episode  117 score -54.12 timesteps: 84135
# episode  118 score -1.18 timesteps: 85135
# episode  119 score -98.74 timesteps: 86135
# episode  120 score -30.81 trailing 10 games avg -34.780 trailing 100 games avg -99.414 timesteps: 87135
# episode  121 score -19.91 timesteps: 88135
# episode  122 score -51.69 timesteps: 89135
# episode  123 score 103.53 timesteps: 90135
# episode  124 score -35.19 timesteps: 91135
# episode  125 score -28.59 timesteps: 92135
# episode  126 score 26.52 timesteps: 93135
# episode  127 score 79.56 timesteps: 94135
# episode  128 score 89.84 timesteps: 95135
# episode  129 score 17.66 timesteps: 96135
# episode  130 score 57.28 trailing 10 games avg 23.900 trailing 100 games avg -64.489 timesteps: 97135
# episode  131 score 85.68 timesteps: 98135
# episode  132 score 9.48 timesteps: 99135
# episode  133 score 35.09 timesteps: 100135
# episode  134 score 0.33 timesteps: 101135
# episode  135 score 30.01 timesteps: 102135
# episode  136 score 58.19 timesteps: 103135
# episode  137 score 95.67 timesteps: 104135
# episode  138 score 87.17 timesteps: 105135
# episode  139 score 8.15 timesteps: 106135
# episode  140 score 98.43 trailing 10 games avg 50.819 trailing 100 games avg -34.792 timesteps: 107135
# episode  141 score -122.53 timesteps: 107523
# episode  142 score 39.08 timesteps: 108523
# episode  143 score -30.25 timesteps: 108906
# episode  144 score 60.97 timesteps: 109906
# episode  145 score 84.78 timesteps: 110906
# episode  146 score -28.26 timesteps: 111906
# episode  147 score -113.41 timesteps: 112906
# episode  148 score -39.87 timesteps: 113906
# episode  149 score 12.00 timesteps: 114906
# episode  150 score 23.28 trailing 10 games avg -11.424 trailing 100 games avg -23.231 timesteps: 115906
# episode  151 score 48.31 timesteps: 116906
# episode  152 score 66.31 timesteps: 117906
# episode  153 score -17.22 timesteps: 118906
# episode  154 score 5.27 timesteps: 119906
# episode  155 score 32.98 timesteps: 120906
# episode  156 score 86.65 timesteps: 121906
# episode  157 score 78.81 timesteps: 122906
# episode  158 score 16.79 timesteps: 123906
# episode  159 score 65.50 timesteps: 124906
# episode  160 score -8.00 trailing 10 games avg 37.540 trailing 100 games avg -6.995 timesteps: 125906
# episode  161 score -0.22 timesteps: 126906
# episode  162 score -6.73 timesteps: 127906
# episode  163 score 89.69 timesteps: 128906
# episode  164 score 32.96 timesteps: 129906
# episode  165 score -232.85 timesteps: 130430
# episode  166 score 125.24 timesteps: 131430
# episode  167 score 97.08 timesteps: 132430
# episode  168 score 87.22 timesteps: 133430
# episode  169 score 63.33 timesteps: 134430
# episode  170 score 113.72 trailing 10 games avg 36.945 trailing 100 games avg 3.672 timesteps: 135430
# episode  171 score 87.27 timesteps: 136430
